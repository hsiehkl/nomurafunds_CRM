# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
onshore = pd.read_csv('onshore.csv', header = 0, sep = ",", encoding = "big5")

# %%
onshore.head()
# Out:
#   accountdate  accountnumber  accountid accountname identifycode  birthdate  \
# 0   2017/8/25         318225    1219493         林ＯＯ   G221******  1977/8/28
# 1   2017/8/17         318201    1219469         黃ＯＯ   Q223******  1994/2/13
# 2   2017/8/29         318232    1219500         林ＯＯ   C121******  1992/12/1
# 3   2017/8/16         318187    1219455         羅ＯＯ   N222******  1965/1/15
# 4    2017/9/5         318259    1219525         葉ＯＯ   B120******  1970/2/26
#
#   gendercode beneficiariescountry beneficiariestype  telephone1  \
# 0          F                   臺灣           個人(自然人)         NaN
# 1          F                   臺灣           個人(自然人)         NaN
# 2          M                   臺灣           個人(自然人)  02XX321748
# 3          F                   臺灣           個人(自然人)         NaN
# 4          M                   臺灣           個人(自然人)  04XX739803
#
#                    ...                    agentcode  agentname  \
# ...

# %%
loc = []
for i in onshore["address1_line1"] :
    loc.append(i[:3])
onshore["loc"] = loc
onshore.head()
# Out:
#   accountdate  accountnumber  accountid accountname identifycode  birthdate  \
# 0   2017/8/25         318225    1219493         林ＯＯ   G221******  1977/8/28
# 1   2017/8/17         318201    1219469         黃ＯＯ   Q223******  1994/2/13
# 2   2017/8/29         318232    1219500         林ＯＯ   C121******  1992/12/1
# 3   2017/8/16         318187    1219455         羅ＯＯ   N222******  1965/1/15
# 4    2017/9/5         318259    1219525         葉ＯＯ   B120******  1970/2/26
#
#   gendercode beneficiariescountry beneficiariestype  telephone1 ...   \
# 0          F                   臺灣           個人(自然人)         NaN ...
# 1          F                   臺灣           個人(自然人)         NaN ...
# 2          M                   臺灣           個人(自然人)  02XX321748 ...
# 3          F                   臺灣           個人(自然人)         NaN ...
# 4          M                   臺灣           個人(自然人)  04XX739803 ...
#
#   agentname  institutioncode institutionname   salescode  salesname  \
# ...

# %%
onshore["loc"].value_counts()
# Out:
# 新北市    20
# 台北市    15
# 高雄市    13
# 台中市    10
# 桃園市     9
# 彰化縣     7
# 台南市     5
# 基隆市     4
# 新竹縣     4
# 新竹市     4
# 苗栗縣     2
# 雲林縣     2
# 屏東縣     1
# 花蓮縣     1
# 嘉義縣     1
# 北縣永     1
# 嘉義市     1
# Name: loc, dtype: int64
